# %% [markdown]
# <center>
# <h2>Capstone Project</h2>
#
# # <span style='color: #81A5FF; '> 👨‍🍳 Exploratory Restaurant Data Analysis and Cleaning </span>
#
# <h3> Group 4 </h3>
#
# <span style='color: #081F4F; font-size: 18px;'>2023/2024</span>
# </center>

# %% [markdown]
# ---------

# %% [markdown]
# The present notebook refers to the section of exploring the extracted restaurant-based data and perform cleaning operations in order to prepare it to be fed into the Flavour Flix platform. Essentially, the key procedures followed throughout this section are:
#
# <span style = 'font-size: 18px;'>
# 🍽 Data integration from multiple sources;  <br>
# 🍽 Handling of missing values;<br>
# 🍽 Handling duplicate data; <br>
# 🍽 Data structure reformatting;<br>
# 🍽 Geocoding;<br>
# 🍽 Text Standardization;<br>
# 🍽 Feature Extraction.<br>
# </span>

# %% [markdown]
# --------

# %% [markdown]
# ### 1. Importing Libraries and Data

# %%
import numpy as np
import pandas as pd

from functions.utils import *
from functions.location import *
from functions.menus import *
from functions.preprocessement import *

#ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option('display.max_columns', None) 
data = pd.read_csv('data/alltheforkscrapes2.csv')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data['restaurantID'] = data['url'].str.split('-r').str[-1]
data.set_index('restaurantID', inplace=True)

# %%
data
# Out:
#                                                         address  averagePrice
# restaurantID
# 730060                    R. José Fontana 10,8200-295,Albufeira            14  \
# 805058                 R. Almeida Garrett 71,8200-272,Albufeira            15
# 712669                         R. da Torre Velha,8200,Albufeira            24
# 576521          Tv. Antero de Quental 4B r/c,8200-296,Albufeira            14
# 802974             R. Alexandre Herculano 11,8200-269,Albufeira            15
# ...                                                         ...           ...
# 501687        Largo da Cruz Velha,4760-107,Vila Nova de Fama...            15
# 724143        Alameda Cónego Joaquim Fernandes 160,4760-884,...            18
# 418275        R. Augusto Correia 42,4760-101,Vila Nova de Fa...            16
# 612699        Av. 25 de Abril 22 4760,4760-101,Vila Nova de ...            25
# 802161        Av. Narciso Ferreira 181,4760-111,Vila Nova de...            13
#
#                          chefName             cuisine currency
# restaurantID
# 730060                        NaN  International food      EUR  \
# 805058                        NaN  International food      EUR
# 712669               Yana Malayko            Japanese      EUR
# 576521        Iqbal Hossain Mohon              Indian      EUR
# 802974            Romilson Santos          Portuguese      EUR
# ...                           ...                 ...      ...
# 501687                        NaN          Portuguese      EUR
# 724143                Gatto Ginno             Italian      EUR
# 418275                        NaN          Portuguese      EUR
# 612699               Miguel Frias          Steakhouse      EUR
# 802161                        NaN            Pizzeria      EUR
#
#                                                customerPhotos/0
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/1
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/2
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/3
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/4
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/5
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/6
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/7
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/8
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                customerPhotos/9
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/10
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/11
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/12
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/13
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/14
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/15
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/16
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/17
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                               customerPhotos/18
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                               customerPhotos/19 description
# restaurantID
# 730060                                                      NaN         NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...         NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...         NaN
# 576521        https://res.cloudinary.com/tf-lab/image/upload...         NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...         NaN
# ...                                                         ...         ...
# 501687                                                      NaN         NaN
# 724143                                                      NaN         NaN
# 418275                                                      NaN         NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...         NaN
# 802161                                                      NaN         NaN
#
#               hasLoyaltyProgram  isBookable   latitude
# restaurantID
# 730060                    False        True  37.089072  \
# 805058                    False        True  37.089072
# 712669                    False        True  37.089072
# 576521                    False        True  37.089072
# 802974                    False        True  37.089072
# ...                         ...         ...        ...
# 501687                    False        True  41.411682
# 724143                    False        True  41.411682
# 418275                    False        True  41.411682
# 612699                    False        True  41.411682
# 802161                    False        True  41.411682
#
#                                       location  longitude  maxPartySize
# restaurantID
# 730060                     Albufeira, Portugal  -8.247880          60.0  \
# 805058                     Albufeira, Portugal  -8.247880           NaN
# 712669                     Albufeira, Portugal  -8.247880          60.0
# 576521                     Albufeira, Portugal  -8.247880          60.0
# 802974                     Albufeira, Portugal  -8.247880           NaN
# ...                                        ...        ...           ...
# 501687        Vila Nova de Famalicão, Portugal  -8.522405          24.0
# 724143        Vila Nova de Famalicão, Portugal  -8.522405          60.0
# 418275        Vila Nova de Famalicão, Portugal  -8.522405          20.0
# 612699        Vila Nova de Famalicão, Portugal  -8.522405          60.0
# 802161        Vila Nova de Famalicão, Portugal  -8.522405           NaN
#
#                                           name                          offer
# restaurantID
# 730060                                Invictus                            NaN  \
# 805058          Galinha da Vizinha - Albufeira  30% off the 'a la carte' menu
# 712669                 Odessa Sushi Restaurant  30% off the 'a la carte' menu
# 576521                                Chutneys           -30% sobre a ementa!
# 802974                                 Audaces  30% off the 'a la carte' menu
# ...                                        ...                            ...
# 501687                   Combinaçao de Sabores                            NaN
# 724143                          Il Gatto Ginno                            NaN
# 418275                      Sabores do Algarve              Menu Executivo €8
# 612699                                   ME.AT  30% off the 'a la carte' menu
# 802161        Rua Gourmet Restaurante Pizzeria  30% off the 'a la carte' menu
#
#                                                    openingHours
# restaurantID
# 730060        Monday 12:00 - 15:00, 17:30 - 23:00\r\nTuesday...  \
# 805058        Monday 12:00 - 22:30\r\nTuesday 12:00 - 22:30\...
# 712669        Monday -\r\nTuesday 18:00 - 22:00\r\nWednesday...
# 576521        Monday 11:30 - 14:30, 18:00 - 24:00\r\nTuesday...
# 802974        Monday -\r\nTuesday 12:00 - 16:00, 19:00 - 24:...
# ...                                                         ...
# 501687        Monday -\r\nTuesday 12:00 - 14:30\r\nWednesday...
# 724143        Monday -\r\nTuesday -\r\nWednesday -\r\nThursd...
# 418275        Monday 10:00 - 24:00\r\nTuesday 10:00 - 24:00\...
# 612699        Monday 12:00 - 15:00, 19:00 - 22:30\r\nTuesday...
# 802161        Monday 12:00 - 22:30\r\nTuesday 12:00 - 22:30\...
#
#               paymentAccepted/0 paymentAccepted/1 paymentAccepted/2
# restaurantID
# 730060        Cabal Credit Card  Cabal Debit Card               NaN  \
# 805058        Cabal Credit Card  Cabal Debit Card      Maestro Card
# 712669        Cabal Credit Card  Cabal Debit Card              Visa
# 576521              Credit Card               NaN               NaN
# 802974        Cabal Credit Card  Cabal Debit Card       Credit Card
# ...                         ...               ...               ...
# 501687         American Express       Credit Card        Mastercard
# 724143                      NaN               NaN               NaN
# 418275              Credit Card        Mastercard              Visa
# 612699              Credit Card        Mastercard              Visa
# 802161        Cabal Credit Card  Cabal Debit Card       Credit Card
#
#              paymentAccepted/3 paymentAccepted/4 paymentAccepted/5
# restaurantID
# 730060                     NaN               NaN               NaN  \
# 805058              Mastercard               NaN               NaN
# 712669                     NaN               NaN               NaN
# 576521                     NaN               NaN               NaN
# 802974            Maestro Card        Mastercard              Visa
# ...                        ...               ...               ...
# 501687           Visa Electron               NaN               NaN
# 724143                     NaN               NaN               NaN
# 418275                     NaN               NaN               NaN
# 612699                     NaN               NaN               NaN
# 802161                     NaN               NaN               NaN
#
#              paymentAccepted/6 paymentAccepted/7 paymentAccepted/8
# restaurantID
# 730060                     NaN               NaN               NaN  \
# 805058                     NaN               NaN               NaN
# 712669                     NaN               NaN               NaN
# 576521                     NaN               NaN               NaN
# 802974           Visa Electron               NaN               NaN
# ...                        ...               ...               ...
# 501687                     NaN               NaN               NaN
# 724143                     NaN               NaN               NaN
# 418275                     NaN               NaN               NaN
# 612699                     NaN               NaN               NaN
# 802161                     NaN               NaN               NaN
#
#                      phone                                              photo
# restaurantID
# 730060                 NaN  https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        3.519654e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 712669        3.519678e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 576521        3.512895e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 802974        3.376629e+10  https://res.cloudinary.com/tf-lab/image/upload...
# ...                    ...                                                ...
# 501687        3.519130e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 724143        3.519134e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 418275                 NaN  https://res.cloudinary.com/tf-lab/image/upload...
# 612699        3.519354e+11  https://res.cloudinary.com/tf-lab/image/upload...
# 802161        3.519126e+11  https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/0
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/1
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/2
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/3
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275        https://res.cloudinary.com/tf-lab/image/upload...
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/4
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521        https://res.cloudinary.com/tf-lab/image/upload...
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/5
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161        https://res.cloudinary.com/tf-lab/image/upload...
#
#                                                        photos/6
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                        photos/7
# restaurantID
# 730060        https://res.cloudinary.com/tf-lab/image/upload...  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                        photos/8
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687        https://res.cloudinary.com/tf-lab/image/upload...
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                        photos/9
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/10
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/11
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143        https://res.cloudinary.com/tf-lab/image/upload...
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/12
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/13
# restaurantID
# 730060                                                      NaN  \
# 805058        https://res.cloudinary.com/tf-lab/image/upload...
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/14
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/15
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/16
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/17
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/18
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/19
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        https://res.cloudinary.com/tf-lab/image/upload...
# 802161                                                      NaN
#
#                                                       photos/20
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699                                                      NaN
# 802161                                                      NaN
#
#                                                       photos/21
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974        https://res.cloudinary.com/tf-lab/image/upload...
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699                                                      NaN
# 802161                                                      NaN
#
#                                                       photos/22
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974                                                      NaN
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699                                                      NaN
# 802161                                                      NaN
#
#                                                       photos/23
# restaurantID
# 730060                                                      NaN  \
# 805058                                                      NaN
# 712669        https://res.cloudinary.com/tf-lab/image/upload...
# 576521                                                      NaN
# 802974                                                      NaN
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699                                                      NaN
# 802161                                                      NaN
#
#                                                       photos/24
# ...
# ...                                     ...                        ...
# 501687                                  NaN                        NaN
# 724143                                  NaN                        NaN
# 418275                                  NaN                        NaN
# 612699                                 10.0                       10.0
# 802161                                  NaN                        NaN
#
#                                            reviewList/17/review
# restaurantID
# 730060                                                      NaN  \
# 805058        New resturant good menu and good value will be...
# 712669        Odessa is a hidden gem of Albufeira. The passi...
# 576521        Excelente vale mesmo a pena para quem gosta de...
# 802974                                                      NaN
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        É sempre bom voltar ao Me.at. \nAdoramos a sua...
# 802161                                                      NaN
#
#              reviewList/17/reviewerName  reviewList/17/serviceRatingValue
# restaurantID
# 730060                              NaN                               NaN  \
# 805058                         David B.                               8.0
# 712669                          Dave F.                              10.0
# 576521                       Claudio O.                              10.0
# 802974                              NaN                               NaN
# ...                                 ...                               ...
# 501687                              NaN                               NaN
# 724143                              NaN                               NaN
# 418275                              NaN                               NaN
# 612699                        Helena s.                              10.0
# 802161                              NaN                               NaN
#
#               reviewList/18/ambienceRatingValue        reviewList/18/date
# restaurantID
# 730060                                      NaN                       NaN  \
# 805058                                      8.0  2023-08-19T20:00:00.000Z
# 712669                                     10.0  2023-07-02T19:00:00.000Z
# 576521                                     10.0  2023-05-12T18:00:00.000Z
# 802974                                      NaN                       NaN
# ...                                         ...                       ...
# 501687                                      NaN                       NaN
# 724143                                      NaN                       NaN
# 418275                                      NaN                       NaN
# 612699                                      8.0  2023-06-24T19:30:00.000Z
# 802161                                      NaN                       NaN
#
#               reviewList/18/foodRatingValue  reviewList/18/ratingValue
# restaurantID
# 730060                                  NaN                        NaN  \
# 805058                                  8.0                        8.0
# 712669                                 10.0                       10.0
# 576521                                 10.0                       10.0
# 802974                                  NaN                        NaN
# ...                                     ...                        ...
# 501687                                  NaN                        NaN
# 724143                                  NaN                        NaN
# 418275                                  NaN                        NaN
# 612699                                 10.0                        9.5
# 802161                                  NaN                        NaN
#
#                                            reviewList/18/review
# restaurantID
# 730060                                                      NaN  \
# 805058                      Bom ambiente, simples e boa comida.
# 712669        O staff é super simpático e atencioso. Descobr...
# 576521        Excellent food and the resturant was bright an...
# 802974                                                      NaN
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        Espaço muito bem decorado, ambiente agradável,...
# 802161                                                      NaN
#
#              reviewList/18/reviewerName  reviewList/18/serviceRatingValue
# restaurantID
# 730060                              NaN                               NaN  \
# 805058                          Jose C.                               8.0
# 712669                        Marina A.                              10.0
# 576521                       Gearóid O.                              10.0
# 802974                              NaN                               NaN
# ...                                 ...                               ...
# 501687                              NaN                               NaN
# 724143                              NaN                               NaN
# 418275                              NaN                               NaN
# 612699                       Cláudia S.                              10.0
# 802161                              NaN                               NaN
#
#               reviewList/19/ambienceRatingValue        reviewList/19/date
# restaurantID
# 730060                                      NaN                       NaN  \
# 805058                                      8.0  2023-08-18T12:00:00.000Z
# 712669                                     10.0  2023-06-30T19:30:00.000Z
# 576521                                     10.0  2023-05-04T17:30:00.000Z
# 802974                                      NaN                       NaN
# ...                                         ...                       ...
# 501687                                      NaN                       NaN
# 724143                                      NaN                       NaN
# 418275                                      NaN                       NaN
# 612699                                      8.0  2023-06-12T18:00:00.000Z
# 802161                                      NaN                       NaN
#
#               reviewList/19/foodRatingValue  reviewList/19/ratingValue
# restaurantID
# 730060                                  NaN                        NaN  \
# 805058                                  8.0                        8.0
# 712669                                 10.0                       10.0
# 576521                                 10.0                       10.0
# 802974                                  NaN                        NaN
# ...                                     ...                        ...
# 501687                                  NaN                        NaN
# 724143                                  NaN                        NaN
# 418275                                  NaN                        NaN
# 612699                                  8.0                        8.0
# 802161                                  NaN                        NaN
#
#                                            reviewList/19/review
# restaurantID
# 730060                                                      NaN  \
# 805058        Very welcoming atmosphere, quick and friendly ...
# 712669                                        Comida excelente!
# 576521                                 Best curry in Albuferia.
# 802974                                                      NaN
# ...                                                         ...
# 501687                                                      NaN
# 724143                                                      NaN
# 418275                                                      NaN
# 612699        Muito agradável, embora ainda calmo, pois foi ...
# 802161                                                      NaN
#
#              reviewList/19/reviewerName  reviewList/19/serviceRatingValue
# restaurantID
# 730060                              NaN                               NaN  \
# 805058                        Samuel C.                               8.0
# 712669                        Brenda A.                              10.0
# 576521                          Dave B.                              10.0
# 802974                              NaN                               NaN
# ...                                 ...                               ...
# 501687                              NaN                               NaN
# 724143                              NaN                               NaN
# 418275                              NaN                               NaN
# 612699                         Pedro C.                               8.0
# 802161                              NaN                               NaN
#
#                              style              tags/0              tags/1
# restaurantID
# 730060              Bachelor party             YUMS x2  International food  \
# 805058                  After work  International food                 NaN
# 712669                    Birthday            Japanese                 NaN
# 576521         Good for ceremonies              Indian                 NaN
# 802974                  After work          Portuguese                 NaN
# ...                            ...                 ...                 ...
# 501687                  After work          Portuguese                 NaN
# 724143        Contemporary cuisine             Italian                 NaN
# 418275           Good for families          Portuguese                 NaN
# 612699            Central location             INSIDER          Steakhouse
# 802161                       Lunch            Pizzeria                 NaN
#
#              tags/2 tags/3 tags/4 tags/5 tags/6 tags/7
# restaurantID
# 730060          NaN    NaN    NaN    NaN    NaN    NaN  \
# 805058          NaN    NaN    NaN    NaN    NaN    NaN
# 712669          NaN    NaN    NaN    NaN    NaN    NaN
# 576521          NaN    NaN    NaN    NaN    NaN    NaN
# 802974          NaN    NaN    NaN    NaN    NaN    NaN
# ...             ...    ...    ...    ...    ...    ...
# 501687          NaN    NaN    NaN    NaN    NaN    NaN
# 724143          NaN    NaN    NaN    NaN    NaN    NaN
# 418275          NaN    NaN    NaN    NaN    NaN    NaN
# 612699          NaN    NaN    NaN    NaN    NaN    NaN
# 802161          NaN    NaN    NaN    NaN    NaN    NaN
#
#                                                             url
# restaurantID
# 730060        https://www.thefork.com/restaurant/invictus-r7...  \
# 805058        https://www.thefork.com/restaurant/galinha-da-...
# 712669        https://www.thefork.com/restaurant/odessa-sush...
# 576521        https://www.thefork.com/restaurant/chutneys-r5...
# 802974        https://www.thefork.com/restaurant/audaces-r80...
# ...                                                         ...
# 501687        https://www.thefork.com/restaurant/combinacao-...
# 724143        https://www.thefork.com/restaurant/il-gatto-gi...
# 418275        https://www.thefork.com/restaurant/sabores-do-...
# 612699         https://www.thefork.com/restaurant/me-at-r612699
# 802161        https://www.thefork.com/restaurant/rua-gourmet...
#
#              paymentAccepted/9 paymentAccepted/10 photos/91 photos/92
# restaurantID
# 730060                     NaN                NaN       NaN       NaN  \
# 805058                     NaN                NaN       NaN       NaN
# 712669                     NaN                NaN       NaN       NaN
# 576521                     NaN                NaN       NaN       NaN
# 802974                     NaN                NaN       NaN       NaN
# ...                        ...                ...       ...       ...
# 501687                     NaN                NaN       NaN       NaN
# 724143                     NaN                NaN       NaN       NaN
# 418275                     NaN                NaN       NaN       NaN
# 612699                     NaN                NaN       NaN       NaN
# 802161                     NaN                NaN       NaN       NaN
#
#              photos/93 photos/94 photos/95 photos/96 photos/97 photos/98
# restaurantID
# 730060             NaN       NaN       NaN       NaN       NaN       NaN  \
# 805058             NaN       NaN       NaN       NaN       NaN       NaN
# 712669             NaN       NaN       NaN       NaN       NaN       NaN
# 576521             NaN       NaN       NaN       NaN       NaN       NaN
# 802974             NaN       NaN       NaN       NaN       NaN       NaN
# ...                ...       ...       ...       ...       ...       ...
# 501687             NaN       NaN       NaN       NaN       NaN       NaN
# 724143             NaN       NaN       NaN       NaN       NaN       NaN
# 418275             NaN       NaN       NaN       NaN       NaN       NaN
# 612699             NaN       NaN       NaN       NaN       NaN       NaN
# 802161             NaN       NaN       NaN       NaN       NaN       NaN
#
#              photos/99 photos/100 photos/101 photos/102 photos/103 photos/104
# restaurantID
# 730060             NaN        NaN        NaN        NaN        NaN        NaN  \
# 805058             NaN        NaN        NaN        NaN        NaN        NaN
# 712669             NaN        NaN        NaN        NaN        NaN        NaN
# 576521             NaN        NaN        NaN        NaN        NaN        NaN
# 802974             NaN        NaN        NaN        NaN        NaN        NaN
# ...                ...        ...        ...        ...        ...        ...
# 501687             NaN        NaN        NaN        NaN        NaN        NaN
# 724143             NaN        NaN        NaN        NaN        NaN        NaN
# 418275             NaN        NaN        NaN        NaN        NaN        NaN
# 612699             NaN        NaN        NaN        NaN        NaN        NaN
# 802161             NaN        NaN        NaN        NaN        NaN        NaN
#
#              photos/105
# restaurantID
# 730060              NaN
# 805058              NaN
# 712669              NaN
# 576521              NaN
# 802974              NaN
# ...                 ...
# 501687              NaN
# 724143              NaN
# 418275              NaN
# 612699              NaN
# 802161              NaN
#
# [2557 rows x 307 columns]

# %%
data = data[~data.index.duplicated(keep='first')]

# %% [markdown]
# ### 2. Summary Statistics

# %%
data.describe()
# Out:
#        averagePrice     latitude    longitude  maxPartySize         phone
# count   1632.000000  1632.000000  1632.000000   1410.000000  9.740000e+02  \
# mean      26.087010    40.169333    -8.305869     51.445390  3.395265e+11
# std       22.778323     3.825969     1.516901     26.795764  6.555813e+10
# min        9.000000    37.019355    -9.381659      4.000000  3.314014e+10
# 25%       15.000000    38.676524    -9.165105     40.000000  3.512184e+11
# 50%       20.000000    38.696861    -8.629105     60.000000  3.512800e+11
# 75%       27.000000    41.157944    -8.247880     60.000000  3.519202e+11
# max      350.000000    53.400002    -2.983333    370.000000  4.478807e+11
#
#              radius  ratingValue   reviewCount
# count  1.632000e+03  1592.000000   1621.000000  \
# mean   7.245232e+13     8.983040    560.998766
# std    4.446549e+13     0.553375    888.559617
# min    5.000000e+03     4.000000      1.000000
# 25%    5.000000e+12     8.800000     87.000000
# 50%    1.000000e+14     9.100000    264.000000
# 75%    1.000000e+14     9.300000    653.000000
# max    1.000000e+14    10.000000  11476.000000
#
#        reviewList/0/ambienceRatingValue  reviewList/0/foodRatingValue
# count                       1583.000000                   1583.000000  \
# mean                           9.080227                      9.163613
# std                            1.697178                      1.760040
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/0/ratingValue  reviewList/0/serviceRatingValue
# count               1583.000000                      1583.000000  \
# mean                   9.147505                         9.182565
# std                    1.568759                         1.715962
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/1/ambienceRatingValue  reviewList/1/foodRatingValue
# count                       1520.000000                   1520.000000  \
# mean                           9.035526                      9.185526
# std                            1.724639                      1.710380
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/1/ratingValue  reviewList/1/serviceRatingValue
# count               1520.000000                      1520.000000  \
# mean                   9.150658                         9.196053
# std                    1.534655                         1.751812
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/2/ambienceRatingValue  reviewList/2/foodRatingValue
# count                       1473.000000                   1473.000000  \
# mean                           9.093007                      9.170401
# std                            1.617722                      1.726990
# min                            2.000000                      2.000000
# 25%                            8.000000                      8.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/2/ratingValue  reviewList/2/serviceRatingValue
# count               1473.000000                      1473.000000  \
# mean                   9.168364                         9.239647
# std                    1.513693                         1.691652
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/3/ambienceRatingValue  reviewList/3/foodRatingValue
# count                       1422.000000                   1422.000000  \
# mean                           9.059072                      9.194093
# std                            1.712856                      1.687898
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/3/ratingValue  reviewList/3/serviceRatingValue
# count               1422.000000                      1422.000000  \
# mean                   9.159634                         9.191280
# std                    1.526280                         1.734278
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/4/ambienceRatingValue  reviewList/4/foodRatingValue
# count                       1391.000000                   1391.000000  \
# mean                           9.079799                      9.181884
# std                            1.605329                      1.602378
# min                            2.000000                      2.000000
# 25%                            8.000000                      8.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/4/ratingValue  reviewList/4/serviceRatingValue
# count               1391.000000                      1391.000000  \
# mean                   9.167505                         9.226456
# std                    1.434285                         1.639369
# min                    2.000000                         2.000000
# 25%                    9.000000                         8.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/5/ambienceRatingValue  reviewList/5/foodRatingValue
# count                       1358.000000                   1358.000000  \
# mean                           9.185567                      9.300442
# std                            1.531597                      1.551717
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/5/ratingValue  reviewList/5/serviceRatingValue
# count               1358.000000                      1358.000000  \
# mean                   9.272091                         9.301915
# std                    1.394196                         1.583401
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/6/ambienceRatingValue  reviewList/6/foodRatingValue
# count                       1330.000000                   1330.000000  \
# mean                           9.094737                      9.186466
# std                            1.639905                      1.663071
# min                            2.000000                      2.000000
# 25%                            8.000000                      8.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/6/ratingValue  reviewList/6/serviceRatingValue
# count               1330.000000                      1330.000000  \
# mean                   9.173684                         9.227068
# std                    1.488071                         1.648910
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/7/ambienceRatingValue  reviewList/7/foodRatingValue
# count                       1298.000000                   1298.000000  \
# mean                           9.149461                      9.212635
# std                            1.629765                      1.628418
# min                            0.000000                      0.000000
# 25%                            8.000000                      8.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/7/ratingValue  reviewList/7/serviceRatingValue
# count               1298.000000                      1298.000000  \
# mean                   9.206086                         9.249615
# std                    1.480566                         1.647672
# min                    0.000000                         0.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/8/ambienceRatingValue  reviewList/8/foodRatingValue
# count                       1256.000000                   1256.000000  \
# mean                           9.136943                      9.248408
# std                            1.574813                      1.599426
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/8/ratingValue  reviewList/8/serviceRatingValue
# count               1256.000000                      1256.000000  \
# mean                   9.222532                         9.256369
# std                    1.400499                         1.604140
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/9/ambienceRatingValue  reviewList/9/foodRatingValue
# count                       1224.000000                   1224.000000  \
# mean                           9.173203                      9.292484
# std                            1.481221                      1.486734
# min                            2.000000                      2.000000
# 25%                            8.000000                     10.000000
# 50%                           10.000000                     10.000000
# 75%                           10.000000                     10.000000
# max                           10.000000                     10.000000
#
#        reviewList/9/ratingValue  reviewList/9/serviceRatingValue
# count               1224.000000                      1224.000000  \
# mean                   9.262663                         9.292484
# std                    1.293042                         1.540750
# min                    2.000000                         2.000000
# 25%                    9.000000                        10.000000
# 50%                   10.000000                        10.000000
# 75%                   10.000000                        10.000000
# max                   10.000000                        10.000000
#
#        reviewList/10/ambienceRatingValue  reviewList/10/foodRatingValue
# count                        1191.000000                    1191.000000  \
# mean                            9.108312                       9.232578
# std                             1.604884                       1.685972
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/10/ratingValue  reviewList/10/serviceRatingValue
# count                1191.000000                       1191.000000  \
# mean                    9.201511                          9.232578
# std                     1.483137                          1.655796
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/11/ambienceRatingValue  reviewList/11/foodRatingValue
# count                        1150.000000                    1150.000000  \
# mean                            9.222609                       9.304348
# std                             1.510339                       1.491338
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/11/ratingValue  reviewList/11/serviceRatingValue
# count                1150.000000                       1150.000000  \
# mean                    9.284783                          9.307826
# std                     1.334415                          1.581285
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/12/ambienceRatingValue  reviewList/12/foodRatingValue
# count                        1125.000000                    1125.000000  \
# mean                            9.189333                       9.292444
# std                             1.477191                       1.501122
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/12/ratingValue  reviewList/12/serviceRatingValue
# count                1125.000000                       1125.000000  \
# mean                    9.262667                          9.276444
# std                     1.335637                          1.618132
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/13/ambienceRatingValue  reviewList/13/foodRatingValue
# count                        1100.000000                    1100.000000  \
# mean                            9.160000                       9.247273
# std                             1.530949                       1.656801
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/13/ratingValue  reviewList/13/serviceRatingValue
# count                1100.000000                       1100.000000  \
# mean                    9.235909                          9.289091
# std                     1.418239                          1.528637
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/14/ambienceRatingValue  reviewList/14/foodRatingValue
# count                        1072.000000                    1072.000000  \
# mean                            9.212687                       9.356343
# std                             1.453772                       1.464130
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/14/ratingValue  reviewList/14/serviceRatingValue
# count                1072.000000                       1072.000000  \
# mean                    9.322295                          9.363806
# std                     1.281702                          1.467391
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/15/ambienceRatingValue  reviewList/15/foodRatingValue
# count                        1052.000000                    1052.000000  \
# mean                            9.222433                       9.285171
# std                             1.422916                       1.490359
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/15/ratingValue  reviewList/15/serviceRatingValue
# count                1052.000000                       1052.000000  \
# mean                    9.290875                          9.370722
# std                     1.292956                          1.497037
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/16/ambienceRatingValue  reviewList/16/foodRatingValue
# count                        1034.000000                    1034.000000  \
# mean                            9.160542                       9.232108
# std                             1.583846                       1.649399
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/16/ratingValue  reviewList/16/serviceRatingValue
# count                1034.000000                       1034.000000  \
# mean                    9.230174                          9.295938
# std                     1.428590                          1.600896
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/17/ambienceRatingValue  reviewList/17/foodRatingValue
# count                        1004.000000                    1004.000000  \
# mean                            9.219124                       9.338645
# std                             1.468782                       1.445887
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/17/ratingValue  reviewList/17/serviceRatingValue
# count                1004.000000                       1004.000000  \
# mean                    9.305777                          9.326693
# std                     1.290593                          1.552294
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/18/ambienceRatingValue  reviewList/18/foodRatingValue
# count                         981.000000                     981.000000  \
# mean                            9.178389                       9.288481
# std                             1.492082                       1.555556
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/18/ratingValue  reviewList/18/serviceRatingValue
# count                 981.000000                        981.000000  \
# mean                    9.285423                          9.386340
# std                     1.310313                          1.432344
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000
#
#        reviewList/19/ambienceRatingValue  reviewList/19/foodRatingValue
# count                         960.000000                     960.000000  \
# mean                            9.139583                       9.314583
# std                             1.521927                       1.481550
# min                             2.000000                       2.000000
# 25%                             8.000000                      10.000000
# 50%                            10.000000                      10.000000
# 75%                            10.000000                      10.000000
# max                            10.000000                      10.000000
#
#        reviewList/19/ratingValue  reviewList/19/serviceRatingValue
# count                 960.000000                        960.000000
# mean                    9.282292                          9.360417
# std                     1.273373                          1.448200
# min                     2.000000                          2.000000
# 25%                     9.000000                         10.000000
# 50%                    10.000000                         10.000000
# 75%                    10.000000                         10.000000
# max                    10.000000                         10.000000

# %%
data.describe(include='object')
# Out:
#                          address      chefName     cuisine currency
# count                       1632           658        1630     1632  \
# unique                      1618           611          56        5
# top     Marina,8500-843,Portimão  Rui Sequeira  Portuguese      EUR
# freq                           3             4         499     1602
#
#                                          customerPhotos/0
# count                                                1540  \
# unique                                               1540
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/1
# count                                                1493  \
# unique                                               1493
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/2
# count                                                1452  \
# unique                                               1452
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/3
# count                                                1416  \
# unique                                               1416
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/4
# count                                                1376  \
# unique                                               1376
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/5
# count                                                1346  \
# unique                                               1346
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/6
# count                                                1311  \
# unique                                               1311
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/7
# count                                                1282  \
# unique                                               1282
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/8
# count                                                1242  \
# unique                                               1242
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                          customerPhotos/9
# count                                                1215  \
# unique                                               1215
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/10
# count                                                1184  \
# unique                                               1184
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/11
# count                                                1155  \
# unique                                               1155
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/12
# count                                                1131  \
# unique                                               1131
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/13
# count                                                1110  \
# unique                                               1110
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/14
# count                                                1082  \
# unique                                               1082
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/15
# count                                                1066  \
# unique                                               1066
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/16
# count                                                1044  \
# unique                                               1044
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/17
# count                                                1019  \
# unique                                               1019
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/18
# count                                                 996  \
# unique                                                996
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                         customerPhotos/19
# count                                                 973  \
# unique                                                973
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                               description          location
# count                                                  25              1522  \
# unique                                                 25                39
# top     Le secret du restaurant Edouard Loubet n'est p...  Almada, Portugal
# freq                                                    1               456
#
#           name                          offer
# count     1632                            524  \
# unique    1629                            126
# top     Raízes  30% off the 'a la carte' menu
# freq         2                            261
#
#                                              openingHours paymentAccepted/0
# count                                                1605              1582  \
# unique                                               1146                15
# top     Monday -\r\nTuesday -\r\nWednesday -\r\nThursd...       Credit Card
# freq                                                   59               903
#
#        paymentAccepted/1 paymentAccepted/2 paymentAccepted/3
# count               1394              1189               713  \
# unique                18                21                14
# top           Mastercard              Visa              Visa
# freq                 568               527               248
#
#        paymentAccepted/4 paymentAccepted/5 paymentAccepted/6
# count                396               224                88  \
# unique                11                 9                 8
# top                 Visa              Visa     Visa Electron
# freq                 150                96                59
#
#        paymentAccepted/7 paymentAccepted/8
# count                 13                 7  \
# unique                 5                 3
# top        Visa Electron     Visa Electron
# freq                   5                 4
#
#                                                     photo
# count                                                1632  \
# unique                                               1632
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/0
# count                                                1632  \
# unique                                               1632
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/1
# count                                                1631  \
# unique                                               1631
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/2
# count                                                1622  \
# unique                                               1622
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/3
# count                                                1584  \
# unique                                               1584
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/4
# count                                                1522  \
# unique                                               1522
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/5
# count                                                1448  \
# unique                                               1448
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/6
# count                                                1350  \
# unique                                               1350
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/7
# count                                                1265  \
# unique                                               1265
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/8
# count                                                1181  \
# unique                                               1181
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                  photos/9
# count                                                1081  \
# unique                                               1081
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/10
# count                                                 953  \
# unique                                                953
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/11
# count                                                 895  \
# unique                                                895
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/12
# count                                                 815  \
# unique                                                815
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/13
# count                                                 753  \
# unique                                                753
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/14
# count                                                 684  \
# unique                                                684
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/15
# count                                                 621  \
# unique                                                621
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/16
# count                                                 594  \
# unique                                                594
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/17
# count                                                 549  \
# unique                                                549
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/18
# count                                                 500  \
# unique                                                500
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/19
# count                                                 457  \
# unique                                                457
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/20
# count                                                 419  \
# unique                                                419
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/21
# count                                                 390  \
# unique                                                390
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/22
# count                                                 359  \
# unique                                                359
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/23
# count                                                 321  \
# unique                                                321
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/24
# count                                                 296  \
# unique                                                296
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/25
# count                                                 269  \
# unique                                                269
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/26
# count                                                 248  \
# unique                                                248
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/27
# count                                                 226  \
# unique                                                226
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/28
# count                                                 200  \
# unique                                                200
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/29
# count                                                 182  \
# unique                                                182
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/30
# count                                                 156  \
# unique                                                156
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/31
# count                                                 148  \
# unique                                                148
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/32
# count                                                 138  \
# unique                                                138
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/33
# count                                                 131  \
# unique                                                131
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/34
# count                                                 122  \
# unique                                                122
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/35
# count                                                 113  \
# unique                                                113
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/36
# count                                                  99  \
# unique                                                 99
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/37
# count                                                  92  \
# unique                                                 92
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/38
# count                                                  84  \
# unique                                                 84
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/39
# count                                                  81  \
# unique                                                 81
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/40
# count                                                  70  \
# unique                                                 70
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/41
# count                                                  64  \
# unique                                                 64
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/42
# count                                                  61  \
# unique                                                 61
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/43
# count                                                  55  \
# unique                                                 55
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/44
# count                                                  51  \
# unique                                                 51
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/45
# count                                                  45  \
# unique                                                 45
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/46
# count                                                  44  \
# unique                                                 44
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/47
# count                                                  44  \
# unique                                                 44
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/48
# count                                                  44  \
# unique                                                 44
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/49
# count                                                  41  \
# unique                                                 41
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/50
# count                                                  40  \
# unique                                                 40
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/51
# count                                                  38  \
# unique                                                 38
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/52
# count                                                  38  \
# unique                                                 38
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/53
# count                                                  37  \
# unique                                                 37
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/54
# count                                                  35  \
# unique                                                 35
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/55
# count                                                  32  \
# unique                                                 32
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/56
# count                                                  31  \
# unique                                                 31
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/57
# count                                                  29  \
# unique                                                 29
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/58
# count                                                  27  \
# unique                                                 27
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/59
# count                                                  26  \
# unique                                                 26
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/60
# count                                                  25  \
# unique                                                 25
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/61
# count                                                  25  \
# unique                                                 25
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/62
# count                                                  24  \
# unique                                                 24
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/63
# count                                                  23  \
# unique                                                 23
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/64
# count                                                  20  \
# unique                                                 20
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/65
# count                                                  20  \
# unique                                                 20
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/66
# count                                                  20  \
# unique                                                 20
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/67
# count                                                  19  \
# unique                                                 19
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/68
# count                                                  19  \
# unique                                                 19
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/69
# count                                                  16  \
# unique                                                 16
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/70
# count                                                  14  \
# unique                                                 14
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/71
# count                                                  13  \
# unique                                                 13
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/72
# count                                                  11  \
# unique                                                 11
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/73
# count                                                  10  \
# unique                                                 10
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/74
# count                                                   9  \
# unique                                                  9
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/75
# count                                                   8  \
# unique                                                  8
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/76
# count                                                   8  \
# unique                                                  8
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/77
# count                                                   7  \
# unique                                                  7
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/78
# count                                                   6  \
# unique                                                  6
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/79
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/80
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/81
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/82
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/83
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/84
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/85
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/86
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/87
# count                                                   5  \
# unique                                                  5
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/88
# count                                                   4  \
# unique                                                  4
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/89
# count                                                   4  \
# unique                                                  4
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/90
# count                                                   3  \
# unique                                                  3
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                reviewList/0/date reviewList/0/review
# count                       1583                1583  \
# unique                       862                1569
# top     2023-09-27T18:30:00.000Z                   .
# freq                          23                   6
#
#        reviewList/0/reviewerName         reviewList/1/date
# count                       1583                      1520  \
# unique                      1402                      1002
# top                       Ana S.  2023-09-20T18:30:00.000Z
# freq                           6                        14
#
#        reviewList/1/review reviewList/1/reviewerName
# count                 1520                      1520  \
# unique                1501                      1342
# top                      .                    Ana S.
# freq                     7                         7
#
#                reviewList/2/date reviewList/2/review
# count                       1473                1473  \
# unique                      1058                1446
# top     2023-09-02T19:00:00.000Z                   .
# freq                           9                  13
#
#        reviewList/2/reviewerName         reviewList/3/date
# count                       1473                      1422  \
# unique                      1332                      1085
# top                       Ana C.  2023-09-09T18:30:00.000Z
# freq                           6                         7
#
#        reviewList/3/review reviewList/3/reviewerName
# count                 1421                      1422  \
# unique                1388                      1267
# top                      .                    Ana F.
# freq                    18                         7
#
#                reviewList/4/date reviewList/4/review
# count                       1391                1391  \
# unique                      1099                1372
# top     2023-09-08T19:30:00.000Z                   .
# freq                           7                   5
#
#        reviewList/4/reviewerName         reviewList/5/date
# count                       1391                      1358  \
# unique                      1231                      1124
# top                      Nuno M.  2023-09-02T12:00:00.000Z
# freq                           4                         6
#
#        reviewList/5/review reviewList/5/reviewerName
# count                 1358                      1358  \
# unique                1337                      1211
# top                      .                       - -
# freq                     8                         6
#
#                reviewList/6/date reviewList/6/review
# count                       1330                1330  \
# unique                      1108                1304
# top     2023-08-15T18:30:00.000Z                   .
# freq                           5                   6
#
#        reviewList/6/reviewerName         reviewList/7/date
# count                       1330                      1298  \
# unique                      1166                      1115
# top                   Ricardo S.  2023-07-29T19:30:00.000Z
# freq                           5                         5
#
#        reviewList/7/review reviewList/7/reviewerName
# count                 1298                      1298  \
# unique                1283                      1163
# top                      .                       - -
# freq                     7                         9
#
#                reviewList/8/date reviewList/8/review
# count                       1256                1256  \
# unique                      1096                1241
# top     2023-08-29T19:30:00.000Z                   .
# freq                           4                   7
#
#        reviewList/8/reviewerName         reviewList/9/date
# count                       1256                      1224  \
# unique                      1113                      1083
# top                          - -  2023-08-26T19:00:00.000Z
# freq                           9                         6
#
#        reviewList/9/review reviewList/9/reviewerName
# count                 1223                      1224  \
# unique                1199                      1107
# top                      .                       - -
# freq                    11                         6
#
#               reviewList/10/date reviewList/10/review
# count                       1191                 1191  \
# unique                      1042                 1177
# top     2023-07-07T12:00:00.000Z                    .
# freq                           3                    7
#
#        reviewList/10/reviewerName        reviewList/11/date
# count                        1191                      1150  \
# unique                       1081                      1031
# top                           - -  2022-12-31T20:00:00.000Z
# freq                            6                         4
#
#        reviewList/11/review reviewList/11/reviewerName
# count                  1150                       1150  \
# unique                 1140                       1041
# top                       .                        - -
# freq                      6                          8
#
#               reviewList/12/date reviewList/12/review
# count                       1125                 1125  \
# unique                       996                 1109
# top     2023-08-19T19:00:00.000Z            Muito bom
# freq                           5                    5
#
#        reviewList/12/reviewerName        reviewList/13/date
# count                        1125                      1100  \
# unique                       1019                       980
# top                           - -  2023-06-24T19:00:00.000Z
# freq                            8                         4
#
#        reviewList/13/review reviewList/13/reviewerName
# count                  1100                       1100  \
# unique                 1079                       1012
# top                       .                        - -
# freq                      8                          7
#
#               reviewList/14/date reviewList/14/review
# count                       1072                 1072  \
# unique                       976                 1059
# top     2023-08-10T18:00:00.000Z                    .
# freq                           3                    8
#
#        reviewList/14/reviewerName        reviewList/15/date
# count                        1072                      1052  \
# unique                        960                       973
# top                           - -  2023-02-11T20:00:00.000Z
# freq                           11                         4
#
#        reviewList/15/review reviewList/15/reviewerName
# count                  1052                       1052  \
# unique                 1035                        963
# top               Muito bom                        - -
# freq                      6                          9
#
#               reviewList/16/date reviewList/16/review
# count                       1034                 1034  \
# unique                       945                 1020
# top     2023-07-23T19:30:00.000Z                    .
# freq                           3                    9
#
#        reviewList/16/reviewerName        reviewList/17/date
# count                        1034                      1004  \
# unique                        947                       932
# top                           - -  2023-07-22T19:30:00.000Z
# freq                            5                         3
#
#        reviewList/17/review reviewList/17/reviewerName
# count                  1004                       1004  \
# unique                  990                        908
# top                       .                        - -
# freq                      7                         15
#
#               reviewList/18/date reviewList/18/review
# count                        981                  981  \
# unique                       908                  968
# top     2023-06-03T18:00:00.000Z            Muito bom
# freq                           4                    6
#
#        reviewList/18/reviewerName        reviewList/19/date
# count                         981                       960  \
# unique                        892                       881
# top                           - -  2023-03-30T19:30:00.000Z
# freq                            9                         3
#
#        reviewList/19/review reviewList/19/reviewerName       style
# count                   960                        960        1571  \
# unique                  944                        882          46
# top                       .                        - -  After work
# freq                      5                         15         534
#
#             tags/0      tags/1             tags/2      tags/3      tags/4
# count         1632         450                162          74          45  \
# unique          46          38                 22          20          18
# top     Portuguese  Portuguese  Accepting my yums  Gift cards  Gift cards
# freq           397          83                 34          24          10
#
#                    tags/5   tags/6   tags/7
# count                  23        7        2  \
# unique                  9        2        1
# top     Accepting my yums  Welcome  Welcome
# freq                    9        4        2
#
#                                                       url paymentAccepted/9
# count                                                1632                 2  \
# unique                                               1632                 1
# top     https://www.thefork.com/restaurant/invictus-r7...     Visa Electron
# freq                                                    1                 2
#
#        paymentAccepted/10                                          photos/91
# count                   1                                                  2  \
# unique                  1                                                  2
# top               Voucher  https://res.cloudinary.com/tf-lab/image/upload...
# freq                    1                                                  1
#
#                                                 photos/92
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/93
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/94
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/95
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/96
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/97
# count                                                   2  \
# unique                                                  2
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/98
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                 photos/99
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/100
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/101
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/102
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/103
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/104
# count                                                   1  \
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1
#
#                                                photos/105
# count                                                   1
# unique                                                  1
# top     https://res.cloudinary.com/tf-lab/image/upload...
# freq                                                    1

# %% [markdown]
# ### 3. Extracting Locations

# %%
locations = data[['name','address', 'location', 'longitude', 'latitude']].copy()

# %%
#Finds last occurence of the address to determine the city
locations['location2'] = locations['address'].map(lambda x: str(x).split(',')[-1])

#Finds the first occurence within "location" to find city -> this was how we eextracted the data
locations['location3'] = locations['location'].map(lambda x: str(x).split(',')[0])

# %%
#Finding indexes from observations not based in Portugal and removing them from the original data and creating a new dataframe with only portuguese location info
foreign_indexes = list((locations[(locations['location'].isna())]).index)
data.drop(foreign_indexes, inplace=True, axis=0)
pt_locations = locations[locations['location'].isna() == False].copy()

# %%
#Pre processing address to further find latitude and longitude coordinates
pt_locations['address'] = pt_locations['address'].apply(preprocess_address)

# %%
# pt_locations[['latitude', 'longitude']] = pt_locations['address'].apply(lambda x: pd.Series(find_coordinates(x)))

# %%
# pt_locations.to_csv('data/portuguese_locations.csv')

# %%
#Step intermédio enquanto o notebook nao estiver finalizado
pt_locations2 = pd.read_csv('data/portuguese_locations.csv', index_col=0)
pt_locations2.rename(columns={'latitude': 'latitude2', 'longitude': 'longitude2'}, inplace=True)
pt_locations_temp = pt_locations.merge(right=pt_locations2, left_on = ['name', 'address', 'location', 'location2'], right_on = ['name', 'address','location', 'location2'], how='inner')
pt_locations_temp.drop_duplicates(keep='first', inplace=True)
pt_locations_temp.index = pt_locations.index

# %%
#data[['address', 'latitude', 'longitude', 'location', 'city']] = pt_locations[['address', 'latitude', 'longitude', 'location2', 'location3']].copy()
data[['address', 'latitude', 'longitude', 'location', 'city']] = pt_locations_temp[['address', 'latitude2', 'longitude2', 'location2', 'location3_y']].copy()

# %% [markdown]
# ### 4. Handling Missing Values and Standardizing Values

# %%
null_columns = data.isnull().any()
null_columns = null_columns[null_columns].index
#list(null_columns)

# %% [markdown]
# #### Chef Name

# %%
data['chefName'] = np.where(data['chefName'].isnull(), 'Not Applicable', data['chefName'])

# %%
data['chefes'] = data['chefName'].apply(get_chef_name)
data['chefName1'] = data['chefes'].apply(lambda x: preprocess_chefs(0, x))
data['chefName2'] = data['chefes'].apply(lambda x: preprocess_chefs(1, x))
data['chefName3'] = data['chefes'].apply(lambda x: preprocess_chefs(2, x))

# %% [markdown]
# #### Standardizing Cuisine

# %%
data['cuisine'].unique()
# Out:
# array(['International food', 'Japanese', 'Indian', 'Portuguese',
#        'Italian', 'Pizzeria', 'International', 'Mediterranean', 'Fusion',
#        'Nepalese', 'European', 'Seafood', 'Vegan cuisine',
#        'Traditional cuisine', 'Steakhouse', 'Regional', 'Greek',
#        'Vegetarian', 'Varied', 'Grilled', 'Thai', 'Mexican', 'Local',
#        'Asian', 'French', 'South American', 'Pub grub', 'Brazilian',
#        'Venezuelan', 'Peruvian', 'Meat Cuisine', 'Korean', 'American',
#        'Toscano', 'Spanish', 'African', 'Syrian', 'Iranian', 'Lebanese',
#        'Cantonese', 'Tibetan', 'Vietnamese', 'Argentinian', 'Pugliese',
#        'Chinese'], dtype=object)

# %%
data['cuisine'] = data['cuisine'].replace({'International food': 'International', 
                                           'Vegan cuisine': 'Vegan',
                                           'Meat Cuisine': 'Meat',
                                           'Toscano': 'Italian', 
                                           'Pugliese': 'Italian', 
                                           'Traditional cuisine': 'Portuguese', 
                                           'Regional': 'Portuguese', 
                                           'Local': 'Portuguese', 
                                           'Cantonese': 'Chinese'})

# %%
data['cuisine_standard'] = data['cuisine'].apply(lambda x: standardize_text(x))

# %% [markdown]
# #### Phone Number

# %%
data['phone'] = data['phone'].astype(str)
data['phone'] = data['phone'].apply(lambda x: x[:-2] if x != 'nan' else 'Not Available')
data['phone'] = data['phone'].apply(lambda x: x[3:12] if len(x) == 12 and x.startswith('351') and x != 'Not Available' else 'Not Available')

# %% [markdown]
# #### Dealing with Schedule Format

# %%
data['openingHours'].fillna('Not Available', inplace=True)

# %%
#Clearing the openingHours column
data['schedule'] = data['openingHours'].apply(lambda x: clean_openinghours(x))

# %% [markdown]
# #### Generating Promotions

# %%
data['promotions'] = data['schedule'].apply(lambda x: promotion_generator(x, 0.5))

# %% [markdown]
# #### Standardizing Locations

# %%
data['location_standard'] = data['location'].apply(lambda x: standardize_location(x))
data['city_standard'] = data['city'].apply(lambda x: standardize_location(x))

# %% [markdown]
# #### Standardizing Style

# %%
data['style'].fillna('Not Available', inplace=True)

# %%
data['style'].unique()
# Out:
# array(['Bachelor party', 'After work', 'Birthday', 'Good for ceremonies',
#        'All you can eat buffet', 'Good for families',
#        'Contemporary cuisine', 'Author', 'Good for groups',
#        'Central location', 'Bistro', 'Not Available', 'Fine Dining',
#        'Cosy', 'Live music', 'Creative', 'Brunch', 'Lunch', 'Traditional',
#        'Bistronomic', 'Good for a business lunch', 'Terrace',
#        'Homemade cuisine', 'Brasserie', 'Garden', 'Oceanfront',
#        'Great view', 'Café', 'Trendy', 'Romantic', 'Restaurant hotel',
#        'Communion', 'Breakfast', 'Winter terrace', 'Nightlife',
#        'With friends', 'Street Food', 'Organic', 'Healthy.old', 'Ethnic',
#        'From market', 'Design', 'Wine bar'], dtype=object)

# %%
data['style'] = data['style'].replace({'Bachelor party': 'Festivities', 
                                       'Good for ceremonies': 'Festivities',
                                       'Birthday': 'Festivities',
                                       'Cosy': 'Chill Out',
                                       'Live music': 'Chill Out',
                                       'Creative': 'Chill Out',
                                       'After work': 'Chill Out',
                                       'Terrace': 'Chill Out',
                                       'Garden': 'Chill Out', 
                                       'Trendy': 'Chill Out',
                                       'Winter terrace': 'Chill Out', 
                                       'Nightlife': 'Chill Out',
                                       'Wine bar': 'Chill Out',
                                       'All you can eat buffet': 'Buffet',
                                       'Good for families': 'Family',
                                       'Romantic': 'Family', 
                                       'Author': 'Fine Dining',
                                       'Bistro': 'Friends',
                                       'Bistronomic': 'Friends', 
                                       'Brasserie': 'Friends', 
                                       'With friends': 'Friends', 
                                       'Good for a business lunch': 'Meetings', 
                                       'Oceanfront': 'View',
                                       'Great view': 'View',
                                       'Café': 'Breakfast', #Aqui não concordo, deverá ser "Café" mesmo
                                       'Communion': 'Groups', 
                                       'Good for groups': 'Groups',
                                       'Organic': 'Homemade', #Aqui não concordo, acho que ficara melhor algo tipo "Healthy"
                                       'From market': 'Homemade', 
                                       'Homemade cuisine': 'Homemade', 
                                       'Traditional': 'Homemade',
                                       'Design': 'Modern', 
                                       'Contemporary cuisine': 'Modern',
                                       'Restaurant hotel': 'Modern',
                                       'Healthy.old': 'Not Available', #Healthy também
                                       'Ethnic': 'Not Available', #Niche?
                                       'Street Food': 'Not Available', #Niche
                                       'Lunch': 'Not Available', #Friends
                                       'Central location': 'Not Available', #Niche
                                       })

# %%
data['style'].value_counts()
# Out:
# style
# Chill Out        678
# Not Available    168
# Family           130
# Modern           119
# Fine Dining      116
# Friends           72
# Meetings          69
# Festivities       57
# Groups            45
# Homemade          35
# Brunch            16
# View              11
# Breakfast          5
# Buffet             1
# Name: count, dtype: int64

# %%
data['style_standard'] = data['style'].apply(lambda x: standardize_text(x))

# %% [markdown]
# #### Defining whether the restaurant has outdoor seating

# %%
data['outdoor_area'] = np.where(random.random() < 0.5, 0, 1)

# %% [markdown]
# #### Defining Random Occupation of the Restaurant

# %%
data['current_occupation'] = data.apply(lambda x: generate_current_occupation(x), axis=1)

# %% [markdown]
# ### 5. Section-Based Analysis

# %% [markdown]
# #### 5.1. Photos

# %%
photos = ['photo', 'customerPhotos/0','customerPhotos/1', 'customerPhotos/2', 'customerPhotos/3', 'customerPhotos/4', 'customerPhotos/5', 'customerPhotos/6',
 'customerPhotos/7', 'customerPhotos/8', 'customerPhotos/9', 'customerPhotos/10', 'customerPhotos/11', 'customerPhotos/12', 'customerPhotos/13',
 'customerPhotos/14', 'customerPhotos/15', 'customerPhotos/16', 'customerPhotos/17', 'customerPhotos/18', 'customerPhotos/19', 'photos/1',
 'photos/2', 'photos/3', 'photos/4', 'photos/5', 'photos/6', 'photos/7','photos/8','photos/9','photos/10', 'photos/11', 'photos/12', 'photos/13', 'photos/14',
 'photos/15','photos/16', 'photos/17', 'photos/18', 'photos/19', 'photos/20', 'photos/21', 'photos/22', 'photos/23', 'photos/24', 'photos/25', 'photos/26', 'photos/27',
 'photos/28', 'photos/29', 'photos/30', 'photos/31', 'photos/32', 'photos/33', 'photos/34', 'photos/35', 'photos/36', 'photos/37', 'photos/38', 'photos/39', 'photos/40',
 'photos/41', 'photos/42', 'photos/43', 'photos/44', 'photos/45', 'photos/46', 'photos/47', 'photos/48', 'photos/49', 'photos/50', 'photos/51', 'photos/52','photos/53',
 'photos/54', 'photos/55', 'photos/56', 'photos/57', 'photos/58', 'photos/59', 'photos/60', 'photos/61', 'photos/62', 'photos/63', 'photos/64', 'photos/65', 'photos/66',
 'photos/67','photos/68','photos/69', 'photos/70', 'photos/71', 'photos/72', 'photos/73', 'photos/74', 'photos/75', 'photos/76', 'photos/77', 'photos/78', 'photos/79',
 'photos/80', 'photos/81', 'photos/82', 'photos/83', 'photos/84', 'photos/85', 'photos/86', 'photos/87', 'photos/88', 'photos/89', 'photos/90',  'photos/91', 'photos/92',
 'photos/93', 'photos/94', 'photos/95', 'photos/96', 'photos/97', 'photos/98', 'photos/99', 'photos/100', 'photos/101', 'photos/102', 'photos/103', 'photos/104', 'photos/105']

# %%
df_photos = data[photos].copy()

# %%
df_photos['photos/1'].unique()

# %% [markdown]
# #### 5.2. Reviews

# %%
restaurant_reviews = data[['name', 'reviewList/0/ambienceRatingValue','reviewList/0/date', 'reviewList/0/foodRatingValue', 'reviewList/0/ratingValue', 'reviewList/0/review',
 'reviewList/0/reviewerName', 'reviewList/0/serviceRatingValue', 'reviewList/1/ambienceRatingValue', 'reviewList/1/date', 'reviewList/1/foodRatingValue', 'reviewList/1/ratingValue',
 'reviewList/1/review', 'reviewList/1/reviewerName', 'reviewList/1/serviceRatingValue', 'reviewList/2/ambienceRatingValue', 'reviewList/2/date', 'reviewList/2/foodRatingValue',
 'reviewList/2/ratingValue', 'reviewList/2/review', 'reviewList/2/reviewerName', 'reviewList/2/serviceRatingValue', 'reviewList/3/ambienceRatingValue','reviewList/3/date',
 'reviewList/3/foodRatingValue', 'reviewList/3/ratingValue', 'reviewList/3/review', 'reviewList/3/reviewerName', 'reviewList/3/serviceRatingValue', 'reviewList/4/ambienceRatingValue',
 'reviewList/4/date','reviewList/4/foodRatingValue', 'reviewList/4/ratingValue', 'reviewList/4/review', 'reviewList/4/reviewerName', 'reviewList/4/serviceRatingValue',
 'reviewList/5/ambienceRatingValue', 'reviewList/5/date', 'reviewList/5/foodRatingValue', 'reviewList/5/ratingValue', 'reviewList/5/review', 'reviewList/5/reviewerName',
 'reviewList/5/serviceRatingValue', 'reviewList/6/ambienceRatingValue', 'reviewList/6/date', 'reviewList/6/foodRatingValue', 'reviewList/6/ratingValue', 'reviewList/6/review',
 'reviewList/6/reviewerName', 'reviewList/6/serviceRatingValue', 'reviewList/7/ambienceRatingValue', 'reviewList/7/date', 'reviewList/7/foodRatingValue', 'reviewList/7/ratingValue',
 'reviewList/7/review', 'reviewList/7/reviewerName', 'reviewList/7/serviceRatingValue', 'reviewList/8/ambienceRatingValue', 'reviewList/8/date', 'reviewList/8/foodRatingValue',
 'reviewList/8/ratingValue', 'reviewList/8/review', 'reviewList/8/reviewerName', 'reviewList/8/serviceRatingValue', 'reviewList/9/ambienceRatingValue', 'reviewList/9/date',
 'reviewList/9/foodRatingValue', 'reviewList/9/ratingValue', 'reviewList/9/review', 'reviewList/9/reviewerName', 'reviewList/9/serviceRatingValue', 'reviewList/10/ambienceRatingValue',
 'reviewList/10/date', 'reviewList/10/foodRatingValue', 'reviewList/10/ratingValue', 'reviewList/10/review', 'reviewList/10/reviewerName', 'reviewList/10/serviceRatingValue',
 'reviewList/11/ambienceRatingValue', 'reviewList/11/date', 'reviewList/11/foodRatingValue', 'reviewList/11/ratingValue', 'reviewList/11/review', 'reviewList/11/reviewerName',
 'reviewList/11/serviceRatingValue', 'reviewList/12/ambienceRatingValue', 'reviewList/12/date', 'reviewList/12/foodRatingValue', 'reviewList/12/ratingValue', 'reviewList/12/review',
 'reviewList/12/reviewerName', 'reviewList/12/serviceRatingValue', 'reviewList/13/ambienceRatingValue', 'reviewList/13/date', 'reviewList/13/foodRatingValue', 'reviewList/13/ratingValue',
 'reviewList/13/review', 'reviewList/13/reviewerName', 'reviewList/13/serviceRatingValue', 'reviewList/14/ambienceRatingValue', 'reviewList/14/date',
 'reviewList/14/foodRatingValue', 'reviewList/14/ratingValue', 'reviewList/14/review', 'reviewList/14/reviewerName', 'reviewList/14/serviceRatingValue', 'reviewList/15/ambienceRatingValue',
 'reviewList/15/date', 'reviewList/15/foodRatingValue', 'reviewList/15/ratingValue', 'reviewList/15/review', 'reviewList/15/reviewerName', 'reviewList/15/serviceRatingValue',
 'reviewList/16/ambienceRatingValue', 'reviewList/16/date', 'reviewList/16/foodRatingValue', 'reviewList/16/ratingValue', 'reviewList/16/review', 'reviewList/16/reviewerName',
 'reviewList/16/serviceRatingValue', 'reviewList/17/ambienceRatingValue', 'reviewList/17/date', 'reviewList/17/foodRatingValue', 'reviewList/17/ratingValue', 'reviewList/17/review',
 'reviewList/17/reviewerName', 'reviewList/17/serviceRatingValue', 'reviewList/18/ambienceRatingValue', 'reviewList/18/date', 'reviewList/18/foodRatingValue', 'reviewList/18/ratingValue',
 'reviewList/18/review', 'reviewList/18/reviewerName', 'reviewList/18/serviceRatingValue', 'reviewList/19/ambienceRatingValue', 'reviewList/19/date', 'reviewList/19/foodRatingValue',
 'reviewList/19/ratingValue', 'reviewList/19/review', 'reviewList/19/reviewerName', 'reviewList/19/serviceRatingValue']].copy()

# %%
restaurant_reviews

# %%
reviews = ['reviewList/0/ambienceRatingValue','reviewList/0/date', 'reviewList/0/foodRatingValue', 'reviewList/0/ratingValue', 'reviewList/0/review',
 'reviewList/0/reviewerName', 'reviewList/0/serviceRatingValue', 'reviewList/1/ambienceRatingValue', 'reviewList/1/date', 'reviewList/1/foodRatingValue', 'reviewList/1/ratingValue',
 'reviewList/1/review', 'reviewList/1/reviewerName', 'reviewList/1/serviceRatingValue', 'reviewList/2/ambienceRatingValue', 'reviewList/2/date', 'reviewList/2/foodRatingValue',
 'reviewList/2/ratingValue', 'reviewList/2/review', 'reviewList/2/reviewerName', 'reviewList/2/serviceRatingValue', 'reviewList/3/ambienceRatingValue','reviewList/3/date',
 'reviewList/3/foodRatingValue', 'reviewList/3/ratingValue', 'reviewList/3/review', 'reviewList/3/reviewerName', 'reviewList/3/serviceRatingValue', 'reviewList/4/ambienceRatingValue',
 'reviewList/4/date','reviewList/4/foodRatingValue', 'reviewList/4/ratingValue', 'reviewList/4/review', 'reviewList/4/reviewerName', 'reviewList/4/serviceRatingValue',
 'reviewList/5/ambienceRatingValue', 'reviewList/5/date', 'reviewList/5/foodRatingValue', 'reviewList/5/ratingValue', 'reviewList/5/review', 'reviewList/5/reviewerName',
 'reviewList/5/serviceRatingValue', 'reviewList/6/ambienceRatingValue', 'reviewList/6/date', 'reviewList/6/foodRatingValue', 'reviewList/6/ratingValue', 'reviewList/6/review',
 'reviewList/6/reviewerName', 'reviewList/6/serviceRatingValue', 'reviewList/7/ambienceRatingValue', 'reviewList/7/date', 'reviewList/7/foodRatingValue', 'reviewList/7/ratingValue',
 'reviewList/7/review', 'reviewList/7/reviewerName', 'reviewList/7/serviceRatingValue', 'reviewList/8/ambienceRatingValue', 'reviewList/8/date', 'reviewList/8/foodRatingValue',
 'reviewList/8/ratingValue', 'reviewList/8/review', 'reviewList/8/reviewerName', 'reviewList/8/serviceRatingValue', 'reviewList/9/ambienceRatingValue', 'reviewList/9/date',
 'reviewList/9/foodRatingValue', 'reviewList/9/ratingValue', 'reviewList/9/review', 'reviewList/9/reviewerName', 'reviewList/9/serviceRatingValue', 'reviewList/10/ambienceRatingValue',
 'reviewList/10/date', 'reviewList/10/foodRatingValue', 'reviewList/10/ratingValue', 'reviewList/10/review', 'reviewList/10/reviewerName', 'reviewList/10/serviceRatingValue',
 'reviewList/11/ambienceRatingValue', 'reviewList/11/date', 'reviewList/11/foodRatingValue', 'reviewList/11/ratingValue', 'reviewList/11/review', 'reviewList/11/reviewerName',
 'reviewList/11/serviceRatingValue', 'reviewList/12/ambienceRatingValue', 'reviewList/12/date', 'reviewList/12/foodRatingValue', 'reviewList/12/ratingValue', 'reviewList/12/review',
 'reviewList/12/reviewerName', 'reviewList/12/serviceRatingValue', 'reviewList/13/ambienceRatingValue', 'reviewList/13/date', 'reviewList/13/foodRatingValue', 'reviewList/13/ratingValue',
 'reviewList/13/review', 'reviewList/13/reviewerName', 'reviewList/13/serviceRatingValue', 'reviewList/14/ambienceRatingValue', 'reviewList/14/date',
 'reviewList/14/foodRatingValue', 'reviewList/14/ratingValue', 'reviewList/14/review', 'reviewList/14/reviewerName', 'reviewList/14/serviceRatingValue', 'reviewList/15/ambienceRatingValue',
 'reviewList/15/date', 'reviewList/15/foodRatingValue', 'reviewList/15/ratingValue', 'reviewList/15/review', 'reviewList/15/reviewerName', 'reviewList/15/serviceRatingValue',
 'reviewList/16/ambienceRatingValue', 'reviewList/16/date', 'reviewList/16/foodRatingValue', 'reviewList/16/ratingValue', 'reviewList/16/review', 'reviewList/16/reviewerName',
 'reviewList/16/serviceRatingValue', 'reviewList/17/ambienceRatingValue', 'reviewList/17/date', 'reviewList/17/foodRatingValue', 'reviewList/17/ratingValue', 'reviewList/17/review',
 'reviewList/17/reviewerName', 'reviewList/17/serviceRatingValue', 'reviewList/18/ambienceRatingValue', 'reviewList/18/date', 'reviewList/18/foodRatingValue', 'reviewList/18/ratingValue',
 'reviewList/18/review', 'reviewList/18/reviewerName', 'reviewList/18/serviceRatingValue', 'reviewList/19/ambienceRatingValue', 'reviewList/19/date', 'reviewList/19/foodRatingValue',
 'reviewList/19/ratingValue', 'reviewList/19/review', 'reviewList/19/reviewerName', 'reviewList/19/serviceRatingValue']

# %%
df_reviews = data[reviews].copy()

# %%
ambience = []
food = []
service = []
for col in df_reviews.columns:
    if 'ambienceRatingValue' in col:
        ambience.append(col)
    elif 'foodRatingValue' in col:
        food.append(col)
    elif 'serviceRatingValue' in col:
        service.append(col)

# %%
#Creating three new columns regarding ratings per category using the mean values of the user-based ratings
df_reviews['ambienceRatingSummary'] = df_reviews[ambience].mean(axis=1)
df_reviews['foodRatingSummary'] = df_reviews[food].mean(axis=1)
df_reviews['serviceRatingSummary'] = df_reviews[service].mean(axis=1)

# %%
data[['ambienceRatingSummary', 'foodRatingSummary', 'serviceRatingSummary']] = df_reviews[['ambienceRatingSummary', 'foodRatingSummary', 'serviceRatingSummary']].copy()

# %% [markdown]
# #### 5.3. Payment Methods

# %%
payments = ['paymentAccepted/0','paymentAccepted/1', 'paymentAccepted/2', 'paymentAccepted/3', 'paymentAccepted/4',
 'paymentAccepted/5', 'paymentAccepted/6', 'paymentAccepted/7', 'paymentAccepted/8', 'paymentAccepted/9', 'paymentAccepted/10']

# %%
df_payments = data[payments].copy()

# %%
df_payments.fillna(0, inplace=True)

# %%
df_payments['paymentAcceptedSummary'] = df_payments.apply(lambda row: [row[col] for col in df_payments.columns if row[col] != 0], axis=1)

# %%
data['paymentAcceptedSummary'] = df_payments['paymentAcceptedSummary'].copy()

# %%
data_exploded_pay = data['paymentAcceptedSummary'].explode()
payment_counts = data_exploded_pay.value_counts()

# %%
payment_counts
# Out:
# paymentAcceptedSummary
# Credit Card          1255
# Visa                 1114
# Mastercard            975
# Visa Electron         519
# Maestro Card          252
# Cabal Debit Card      221
# Cabal Credit Card     218
# American Express      203
# MobilePay             152
# Apple Pay              54
# Cash Only              37
# Diners Club Card       22
# Voucher                20
# Check                   7
# Bancontact              5
# Elo                     3
# Clave Debit Card        2
# Sodexo                  2
# Rede Shop               1
# EC card                 1
# Clave Credit Card       1
# Name: count, dtype: int64

# %%
#Replace 'Cash Only' with 'Cash'
data['paymentAcceptedSummary'] = [x if 'Cash Only' not in x else [item.replace('Cash Only', 'Cash') for item in x] for x in data['paymentAcceptedSummary']]

#Replace 'Elo', 'Cabal Credit Card', 'Cabal', 'MobilePay', 'Rede Shop', 'Clave', 'EC Card' with 'MBWay'
data['paymentAcceptedSummary'] = [ [item if item not in ['Elo', 'Cabal Credit Card', 'Cabal Debit Card', 'MobilePay', 'Rede Shop',
                                                         'Clave Debit Card', 'Clave Credit Card', 'EC card'] else 'MBWay' for item in x]
                                  for x in data['paymentAcceptedSummary']]

# Eleminate duplicates from the list
data['paymentAcceptedSummary'] = [set(x) for x in data['paymentAcceptedSummary']]

# %% [markdown]
# #### 5.4. Tags

# %%
df_tags = data[['tags/0','tags/1', 'tags/2', 'tags/3', 'tags/4', 'tags/5', 'tags/6', 'tags/7',]].copy()
df_tags

# %%
df_tags['michelin'] = df_tags.apply(lambda row: 1 if 'MICHELIN' in row.values else 0, axis=1)

# %%
data['michelin'] = df_tags['michelin'].copy()

# %% [markdown]
# ### 6. Workable data definition

# %%
df_workable = data[['url', 'name', 'address', 'photo', 'averagePrice', 
                    'chefName1', 'chefName2', 'chefName3', 
                    'cuisine', 'michelin',
                    'description',  'isBookable', 'maxPartySize',
                    'schedule', 'promotions', 'phone', 'photo', 
                    'ratingValue', 'reviewCount', 'style',
                    'latitude', 'longitude', 'location', 'city', 
                    'ambienceRatingSummary', 'foodRatingSummary', 'serviceRatingSummary', 'paymentAcceptedSummary', 'outdoor_area','current_occupation']].copy()

data['paymentsSummarystr'] = data['paymentAcceptedSummary'].apply(lambda x: str(x))
data['name_standard'] = data['name'].apply(lambda x: standardize_text(x))
data['paymentsSummarystr_standard'] = data['paymentsSummarystr'].apply(lambda x: standardize_text(x))
df_standards = data[['name_standard', 'cuisine_standard', 'style_standard', 'city_standard', 'location_standard', 'paymentsSummarystr_standard']].copy()

# %% [markdown]
# ### 7. Menu integration

# %%
menu_df = pd.read_csv('data/almost_clean_menus.csv')

# %%
df_workable = df_workable.merge(menu_df, left_on = 'url', right_on='input', how='left')

# %%
df_workable.drop(['input'], axis=1, inplace=True)

# %%
#Temos de re-correr isto :(
df_workable.to_csv('data/preprocessed_data.csv', index=True)

# %% [markdown]
# # A partir daqui não conta para este notebook

# %% [markdown]
# ### Restaurants Near You

# %%
df_workable = pd.read_csv('data/preprocessed_data.csv')

# %%
df1 = df_workable[df_workable['location'] == 'Lisbon']
shaul = Location()
shaul.getLocation()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\carolinashaul\Documents\GitHub\FlavourFlix\EDA_Restaurant.ipynb Cell 90 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/carolinashaul/Documents/GitHub/FlavourFlix/EDA_Restaurant.ipynb#Y153sZmlsZQ%3D%3D?line=0'>1</a> df1 = df_workable[df_workable['location'] == 'Lisbon']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/carolinashaul/Documents/GitHub/FlavourFlix/EDA_Restaurant.ipynb#Y153sZmlsZQ%3D%3D?line=1'>2</a> shaul = Location()
#       <a href='vscode-notebook-cell:/c%3A/Users/carolinashaul/Documents/GitHub/FlavourFlix/EDA_Restaurant.ipynb#Y153sZmlsZQ%3D%3D?line=2'>3</a> shaul.getLocation()
#
# File c:\Users\carolinashaul\Documents\GitHub\FlavourFlix\functions\location.py:86, in Location.__init__(self, latitude, longitude, region, city)
#      84 self.city = city
#      85 #self.__api_key = "AoqezzGOUEoJevKSMBGmvvseepc9ryhMu2YQkccOhaCKLXUG2snUIPxGkDNsRvYP"
# ---> 86 self.__api_key = local_settings.GET_CURRENT_LOCATION_KEY
#
# NameError: name 'local_settings' is not defined

# %%
df1 = nearYou(shaul, df1, 10)

# %%
df1['minutes_away'] = df1.apply(lambda row: shaul.getDirections(row['latitude'], row['longitude'], ['driving'])['driving'].minutes, axis=1)

# %%
df1
# Out:
#                                                     url  \
# 930   https://www.thefork.com/restaurant/valle-flor-...
# 726   https://www.thefork.com/restaurant/basilio-r66...
# 1037  https://www.thefork.com/restaurant/sopinhas-re...
# 713   https://www.thefork.com/restaurant/antiga-wine...
# 1018  https://www.thefork.com/restaurant/petiscos-da...
# 1041  https://www.thefork.com/restaurant/nicolau-lis...
# 929   https://www.thefork.com/restaurant/tapas-n-fri...
# 757   https://www.thefork.com/restaurant/ajitama-ram...
# 938   https://www.thefork.com/restaurant/organi-chia...
# 984   https://www.thefork.com/restaurant/tapas-n-fri...
#
#                                 name  \
# 930                       Valle Flor
# 726                          Basílio
# 1037            Sopinhas Restaurante
# 713                  Antiga Wine Bar
# 1018               Petiscos da Prata
# 1041                  Nicolau Lisboa
# 929    Tapas N Friends - São Nicolau
# 757   Ajitama Ramen Bistro - Alecrim
# 938                  Organi - Chiado
# 984         Tapas N Friends - Chiado
#
#                                                 address  \
# 930         R. Jau 54 - Pestana Palace,Lisbon, Portugal
# 726           Rua dos Bacalhoeiros 111,Lisbon, Portugal
# 1037                 R. da Madalena 50,Lisbon, Portugal
# 713    Rua de Santo Antonio da Sé - 10,Lisbon, Portugal
# 1018                   Rua da Prata 88,Lisbon, Portugal
# 1041              R. de São Nicolau 17,Lisbon, Portugal
# 929                 Rua São Nicolau 49,Lisbon, Portugal
# 757   R. do Alecrim 47A, 1200-014 Lisboa, Portugal,L...
# 938   Calçada Nova de São Francisco, 2,Lisbon, Portugal
# 984   Calçada Nova de São Francisco nº14,Lisbon, Por...
#
#                                                   photo  averagePrice  \
# 930   https://res.cloudinary.com/tf-lab/image/upload...            45
# 726   https://res.cloudinary.com/tf-lab/image/upload...            14
# 1037  https://res.cloudinary.com/tf-lab/image/upload...            15
# 713   https://res.cloudinary.com/tf-lab/image/upload...            18
# 1018  https://res.cloudinary.com/tf-lab/image/upload...            30
# 1041  https://res.cloudinary.com/tf-lab/image/upload...            14
# 929   https://res.cloudinary.com/tf-lab/image/upload...            19
# 757   https://res.cloudinary.com/tf-lab/image/upload...            19
# 938   https://res.cloudinary.com/tf-lab/image/upload...            15
# 984   https://res.cloudinary.com/tf-lab/image/upload...            18
#
#                  chefName1       chefName2       chefName3        cuisine  \
# 930   Pedro Ingles Marques  Not Applicable  Not Applicable  International
# 726         Not Applicable  Not Applicable  Not Applicable  International
# 1037        Not Applicable  Not Applicable  Not Applicable  International
# 713         Not Applicable  Not Applicable  Not Applicable       European
# 1018        Mauro de Sousa  Not Applicable  Not Applicable  Mediterranean
# 1041        Not Applicable  Not Applicable  Not Applicable  International
# 929         Not Applicable  Not Applicable  Not Applicable     Portuguese
# 757         Not Applicable  Not Applicable  Not Applicable       Japanese
# 938         Not Applicable  Not Applicable  Not Applicable  Vegan cuisine
# 984         Not Applicable  Not Applicable  Not Applicable     Portuguese
#
#       michelin  ...    city  ambienceRatingSummary  foodRatingSummary  \
# 930          0  ...  Almada              10.000000          10.000000
# 726          0  ...  Almada               9.100000           9.300000
# 1037         0  ...  Almada               7.750000           8.750000
# 713          0  ...  Almada               9.300000           9.600000
# 1018         0  ...  Almada               9.555556           9.555556
# 1041         0  ...  Almada               9.200000           9.000000
# 929          0  ...  Almada               8.000000           8.000000
# 757          0  ...  Almada               9.300000           9.700000
# 938          0  ...  Almada               9.200000           9.500000
# 984          0  ...  Almada               9.000000           8.500000
#
#      serviceRatingSummary                             paymentAcceptedSummary  \
# 930             10.000000  {'Visa', 'American Express', 'Credit Card', 'M...
# 726              8.100000                                    {'Credit Card'}
# 1037             8.500000                          {'Visa Electron', 'Visa'}
# 713              9.500000  {'Visa', 'Visa Electron', 'Credit Card', 'Mast...
# 1018             9.111111         {'American Express', 'Visa', 'Mastercard'}
# 1041             8.700000                                    {'Credit Card'}
# 929              8.142857                          {'Visa Electron', 'Visa'}
# 757              9.400000                            {'Credit Card', 'Visa'}
# 938              9.700000   {'Visa', 'Voucher', 'Credit Card', 'Mastercard'}
# 984              9.200000                          {'Visa Electron', 'Visa'}
#
#      outdoor_area current_occupation  \
# 930             1                  0
# 726             1                  0
# 1037            1                  0
# 713             1                  9
# 1018            1                  0
# 1041            1                  0
# 929             1                 16
# 757             1                 41
# 938             1                 18
# 984             1                 25
#
#                                           menu_pre_proc  haversine_distances  \
# 930   {'A la carte': {'Antes do prato (por pessoa)':...           193.561132
# 726                                                 NaN           193.718085
# 1037  {'Couvert': {'Pão': {'isMainDish': False, 'pri...           193.794823
# 713   {'Dishes To Share': {'Basket Of Sao Lourenco B...           193.852907
# 1018                                                NaN           193.909370
# 1041  {'Entradas': {'Sopa Do Dia': {'isMainDish': Fa...           193.941286
# 929   {'Starter': {'Cesto de pão': {'isMainDish': Fa...           193.949540
# 757   {'Entradas': {'Padron togarashi': {'isMainDish...           193.951299
# 938   {'Entradas': {'Pão de arroz (2 px)': {'isMainD...           194.032660
# 984   {'Tapas para partilhar': {'Cesto de pão (pão a...           194.044031
#
#      minutes_away
# 930           128
# 726           130
# 1037          131
# 713           129
# 1018          128
# 1041          132
# 929           129
# 757           128
# 938           128
# 984           129
#
# [10 rows x 33 columns]

# %% [markdown]
# ##  __Painel de Analytics (primeira página)__:
# - dizer quantos restaurantes se encontraram perto (Fazer um plot);
# - nome do restaurante mais próximo e distancia;
# - qual o tipo de comida mais comum próximo;
# - Qual o average price da comdia proximo;
# - Qual o restaurante mais top rated e mesmo a nível de coisas especificas (ambiente, comida);
# - Promoções perto.
# - User poderá escolher a data para ver os restaurantes abertps;

# %%
import folium

m = folium.Map(location=(shaul.latitude, shaul.longitude), zoom_start=7, tiles="cartodb positron")
for index, row in df1.iterrows():
    # Create a marker for each observation
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['name'],  # Display the name in a popup
    ).add_to(m)

m

# %%
df1['averagePrice'].median()

# %%
df1['cuisine'].value_counts()

# %%
df1[df1['minutes_away'] == df1['minutes_away'].min()]

# %%
df1[df1['ratingValue'] == df1['ratingValue'].max()]

# %%
df1[df1['foodRatingSummary'] == df1['foodRatingSummary'].max()]

# %%
df1[df1['ambienceRatingSummary'] == df1['ambienceRatingSummary'].max()]

# %%
df1[df1['serviceRatingSummary'] == df1['serviceRatingSummary'].max()]

# %%
df1[df1['promotions'] != 'No Offers']
